# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

tf.set_random_seed(1)
np.random.seed(1)

# fake data
# 产生100行2列，值为1的数组
n_data = np.ones((100, 2))
# 产生100行2列，均值为2，标准差为1的正态分布
x0 = np.random.normal(2*n_data, 1)      # class0 x shape=(100, 2)
# 产生100个值为0的数组
y0 = np.zeros(100)                      # class0 y shape=(100, 1)
# 产生100行2列，均值为-2，标准差为1的正态分布
x1 = np.random.normal(-2*n_data, 1)     # class1 x shape=(100, 2)
# 产生100个值为1的数组
y1 = np.ones(100)                       # class1 y shape=(100, 1)

# 产生200行2列数组（将x1以行扩展的方式，拼接到x0后面）
x = np.vstack((x0, x1))  # shape (200, 2) + some noise
# 将y1以列扩展的方式，拼接到y0后面
y = np.hstack((y0, y1))  # shape (200, )

# plot data
# x第一列为x，第二列为y，画点
plt.scatter(x[:, 0], x[:, 1], c=y, s=100, lw=0, cmap='RdYlGn')
plt.show()

tf_x = tf.placeholder(tf.float32, x.shape)     # input x
tf_y = tf.placeholder(tf.int32, y.shape)     # input y

# neural network layers
# DenseNet 稠密卷积神经层处理
l1 = tf.layers.dense(tf_x, 10, tf.nn.relu)          # hidden layer
output = tf.layers.dense(l1, 2)                     # output layer

loss = tf.losses.sparse_softmax_cross_entropy(labels=tf_y, logits=output)           # compute cost
accuracy = tf.metrics.accuracy(          # return (acc, update_op), and create 2 local variables
    labels=tf.squeeze(tf_y), predictions=tf.argmax(output, axis=1),)[1]
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.05)
train_op = optimizer.minimize(loss)

sess = tf.Session()                                                                 # control training and others
init_op = tf.group(tf.global_variables_initializer(), tf.local_variables_initializer())
sess.run(init_op)     # initialize var in graph

plt.ion()   # something about plotting
for step in range(100):
    # train and net output
    _, acc, pred = sess.run([train_op, accuracy, output], {tf_x: x, tf_y: y})
    print(pred)
    if step % 2 == 0:
        # plot and show learning process
        plt.cla()
        plt.scatter(x[:, 0], x[:, 1], c=pred.argmax(1), s=100, lw=0, cmap='RdYlGn')
        plt.text(1.5, -4, 'Accuracy=%.2f' % acc, fontdict={'size': 20, 'color': 'red'})
        plt.pause(0.1)

plt.ioff()
plt.show()
# Out:
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# Tensor("dense_39/BiasAdd:0", shape=(200, 2), dtype=float32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-cf79833fed59> in <module>()
#      56         plt.scatter(x[:, 0], x[:, 1], c=pred.argmax(1), s=100, lw=0, cmap='RdYlGn')
#      57         plt.text(1.5, -4, 'Accuracy=%.2f' % acc, fontdict={'size': 20, 'color': 'red'})
# ---> 58         plt.pause(0.1)
#      59
#      60 plt.ioff()
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in pause(interval)
#     291             canvas.draw_idle()
#     292         show(block=False)
# --> 293         canvas.start_event_loop(interval)
#     294     else:
#     295         time.sleep(interval)
#
# D:\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backend_bases.py in start_event_loop(self, timeout)
#    2444         while self._looping and counter * timestep < timeout:
#    2445             self.flush_events()
# -> 2446             time.sleep(timestep)
#    2447             counter += 1
#    2448
#
# KeyboardInterrupt:
