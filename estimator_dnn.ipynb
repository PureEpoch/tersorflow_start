# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
from six.moves.urllib.request import urlopen

import numpy as np
import tensorflow as tf

# Data sets
IRIS_TRAINING = "iris_training.csv"
IRIS_TRAINING_URL = "http://download.tensorflow.org/data/iris_training.csv"

IRIS_TEST = "iris_test.csv"
IRIS_TEST_URL = "http://download.tensorflow.org/data/iris_test.csv"

def main():
  # If the training and test sets aren't stored locally, download them.
  if not os.path.exists(IRIS_TRAINING):
    raw = urlopen(IRIS_TRAINING_URL).read()
    with open(IRIS_TRAINING, "wb") as f:
      f.write(raw)

  if not os.path.exists(IRIS_TEST):
    raw = urlopen(IRIS_TEST_URL).read()
    with open(IRIS_TEST, "wb") as f:
      f.write(raw)

  # Load datasets.
  training_set = tf.contrib.learn.datasets.base.load_csv_with_header(
      filename=IRIS_TRAINING,
      target_dtype=np.int,
      features_dtype=np.float32)
  test_set = tf.contrib.learn.datasets.base.load_csv_with_header(
      filename=IRIS_TEST,
      target_dtype=np.int,
      features_dtype=np.float32)

  # Specify that all features have real-value data
  feature_columns = [tf.feature_column.numeric_column("x", shape=[4])]

  # Build 3 layer DNN with 10, 20, 10 units respectively.
  #classifier = tf.estimator.DNNClassifier(feature_columns=feature_columns,
  #                                        hidden_units=[10, 20, 10],
  #                                        n_classes=3,
  #                                        model_dir="/tmp/iris_model")
    
  estimator = tf.contrib.learn.DNNClassifier(
    feature_columns=feature_columns,
    hidden_units=[10, 20, 10],
    n_classes=2,
    model_dir="./tmp/iris_model",
    optimizer=tf.train.ProximalAdagradOptimizer(
      learning_rate=0.1,
      l1_regularization_strength=0.001
    ))  
  # Define the training inputs
  train_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": np.array(training_set.data)},
      y=np.array(training_set.target),
      num_epochs=None,
      shuffle=True)

  # Train model.
  estimator.fit(input_fn=train_input_fn, steps=2000)

  # Define the test inputs
  test_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": np.array(test_set.data)},
      y=np.array(test_set.target),
      num_epochs=1,
      shuffle=False)

  # Evaluate accuracy.
  accuracy_score = estimator.evaluate(input_fn=test_input_fn)

  print("##################################")
  print(accuracy_score)
 # print("\nTest Accuracy: {0:f}\n".format(accuracy_score))

  # Classify two new flower samples.
  new_samples = np.array(
      [[6.4, 3.2, 4.5, 1.5],
       [5.8, 3.1, 5.0, 1.7]], dtype=np.float32)
  predict_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": new_samples},
      num_epochs=1,
      shuffle=False)

  predictions = estimator.predict_classes(input_fn=predict_input_fn)
  print(predictions)
  predicted_classes = [p["classes"] for p in predictions]

  print(
      "New Samples, Class Predictions:    {}\n"
      .format(predicted_classes))

if __name__ == "__main__":
    main()
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000000012071BA8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': './tmp/iris_model'}
# WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:Casting <dtype: 'int32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int32'> labels to bool.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ./tmp/iris_model\model.ckpt-6000
# INFO:tensorflow:Saving checkpoints for 6001 into ./tmp/iris_model\model.ckpt.
# INFO:tensorflow:loss = -5.02781e+08, step = 6001
# INFO:tensorflow:global_step/sec: 454.52
# INFO:tensorflow:loss = -5.07559e+08, step = 6101 (0.218 sec)
# INFO:tensorflow:global_step/sec: 518.105
# INFO:tensorflow:loss = -5.42257e+08, step = 6201 (0.194 sec)
# INFO:tensorflow:global_step/sec: 483.064
# INFO:tensorflow:loss = -6.24294e+08, step = 6301 (0.212 sec)
# INFO:tensorflow:global_step/sec: 480.742
# INFO:tensorflow:loss = -6.7083e+08, step = 6401 (0.210 sec)
# INFO:tensorflow:global_step/sec: 454.52
# INFO:tensorflow:loss = -5.09983e+08, step = 6501 (0.216 sec)
# INFO:tensorflow:global_step/sec: 431.009
# INFO:tensorflow:loss = -6.95611e+08, step = 6601 (0.228 sec)
# INFO:tensorflow:global_step/sec: 507.585
# INFO:tensorflow:loss = -6.45666e+08, step = 6701 (0.198 sec)
# INFO:tensorflow:global_step/sec: 487.777
# INFO:tensorflow:loss = -5.60001e+08, step = 6801 (0.210 sec)
# INFO:tensorflow:global_step/sec: 492.583
# INFO:tensorflow:loss = -6.74034e+08, step = 6901 (0.206 sec)
# INFO:tensorflow:global_step/sec: 299.384
# INFO:tensorflow:loss = -7.3528e+08, step = 7001 (0.333 sec)
# INFO:tensorflow:global_step/sec: 289.838
# INFO:tensorflow:loss = -6.00016e+08, step = 7101 (0.343 sec)
# INFO:tensorflow:global_step/sec: 272.464
# INFO:tensorflow:loss = -7.55892e+08, step = 7201 (0.368 sec)
# INFO:tensorflow:global_step/sec: 409.813
# INFO:tensorflow:loss = -7.9493e+08, step = 7301 (0.238 sec)
# INFO:tensorflow:global_step/sec: 492.582
# INFO:tensorflow:loss = -7.50913e+08, step = 7401 (0.209 sec)
# INFO:tensorflow:global_step/sec: 490.168
# INFO:tensorflow:loss = -8.6631e+08, step = 7501 (0.197 sec)
# INFO:tensorflow:global_step/sec: 490.169
# INFO:tensorflow:loss = -9.22729e+08, step = 7601 (0.209 sec)
# INFO:tensorflow:global_step/sec: 444.419
# INFO:tensorflow:loss = -6.41233e+08, step = 7701 (0.221 sec)
# INFO:tensorflow:global_step/sec: 476.163
# INFO:tensorflow:loss = -7.36833e+08, step = 7801 (0.214 sec)
# INFO:tensorflow:global_step/sec: 440.503
# INFO:tensorflow:loss = -9.06431e+08, step = 7901 (0.223 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into ./tmp/iris_model\model.ckpt.
# INFO:tensorflow:Loss for final step: -8.05142e+08.
# WARNING:tensorflow:From D:\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\contrib\learn\python\learn\estimators\head.py:625: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# WARNING:tensorflow:Casting <dtype: 'int32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-12:02:46
# INFO:tensorflow:Restoring parameters from ./tmp/iris_model\model.ckpt-8000
# INFO:tensorflow:Finished evaluation at 2017-11-16-12:02:47
# INFO:tensorflow:Saving dict for global step 8000: accuracy = 0.566667, accuracy/baseline_label_mean = 1.0, accuracy/threshold_0.500000_mean = 0.566667, auc = 0.6875, auc_precision_recall = 0.907407, global_step = 8000, labels/actual_label_mean = 1.0, labels/prediction_mean = 0.9, loss = -7.02753e+08, precision/positive_threshold_0.500000_mean = 0.814815, recall/positive_threshold_0.500000_mean = 1.0
# ##################################
# {'loss': -7.0275315e+08, 'accuracy': 0.56666666, 'labels/prediction_mean': 0.89999998, 'labels/actual_label_mean': 1.0, 'accuracy/baseline_label_mean': 1.0, 'auc': 0.68749988, 'auc_precision_recall': 0.90740734, 'accuracy/threshold_0.500000_mean': 0.56666666, 'precision/positive_threshold_0.500000_mean': 0.81481481, 'recall/positive_threshold_0.500000_mean': 1.0, 'global_step': 8000}
# INFO:tensorflow:Restoring parameters from ./tmp/iris_model\model.ckpt-8000
# <generator object DNNClassifier.predict_classes.<locals>.<genexpr> at 0x000000000F747AF0>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-f9c8e2fb8747> in <module>()
#      98
#      99 if __name__ == "__main__":
# --> 100     main()
#
# <ipython-input-11-f9c8e2fb8747> in main()
#      91   predictions = estimator.predict_classes(input_fn=predict_input_fn)
#      92   print(predictions)
# ---> 93   predicted_classes = [p["classes"] for p in predictions]
#      94
#      95   print(
#
# <ipython-input-11-f9c8e2fb8747> in <listcomp>(.0)
#      91   predictions = estimator.predict_classes(input_fn=predict_input_fn)
#      92   print(predictions)
# ---> 93   predicted_classes = [p["classes"] for p in predictions]
#      94
#      95   print(
#
# IndexError: invalid index to scalar variable.
